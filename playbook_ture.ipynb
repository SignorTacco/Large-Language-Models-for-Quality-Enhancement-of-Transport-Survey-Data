# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# %%
def show_scrollable(df, max_rows=20, height=400):
    html = df.head(max_rows).to_html(notebook=True)
    display(HTML(f'<div style="overflow:auto; height:{height}px">{html}</div>'))

# %%
after_Ture = pd.read_csv('Data\EfterkodTur_Nicola.csv', encoding='latin1')
df_Ture = pd.read_csv('Data\TuTure_Nicola.csv', encoding='latin1')

# %%
df_Ture
# Out:
#           turid  sessionid  turnr  tiladrflag             tiladrsogeord  \
# 0       2118077     347009      1           4  Ahornvej 30 2970 Hørshol
# 1       2118078     347009      2           1                       NaN
# 2       2118081     347010      3           4           Høsterkøb kirke
# 3       2118082     347010      4           1                       NaN
# 4       2118083     347013      1           4    Gevninge Bygade 2 4000
# ...         ...        ...    ...         ...                       ...
# 233519  2747013     538780      2           4      Havnen 27, 4600 Køge
# 233520  2747014     538780      3           1                       NaN
# 233521  2747056     538797      2           1                       NaN
# 233522  2747120     538818      1           6                       NaN
# 233523  2747123     538818      2           1                       NaN
#
#            tiladrid  tiladrstedid  \
# 0       2230102030_           0.0
# 1       2230548038_           0.0
# 2       2300226286_      166952.0
# 3       2300323083_           0.0
# 4       3500224002_      158249.0
# ...             ...           ...
# 233519  2593477027_           0.0
# 233520  1015044005_           0.0
# 233521  1470475110_           0.0
# 233522  4615714001_           0.0
# 233523  4616650016_           0.0
#
#                                                tiladrtext  tiladrn  tiladre  \
# 0                              Ahornvej 30, 2970 Hørsholm  6199137   718433
# 1                             Bellisvej 38, 2970 Hørsholm  6198520   718307
# 2         HØSTERKØB KIRKE, Gøngehusvej 286, 2970 Hørsholm  6195042   718391
# 3                         Keilstruplund 83, 3460 Birkerød  6193548   715687
# 4       Dagli´Brugsen, Gevninge Bygade 2, Gevninge, 40...  6170097   686374
# ...                                                   ...      ...      ...
# 233519                               Havnen 27, 4600 Køge  6150077   701552
# 233520            Nordre Frihavnsgade 5, 2100 København Ø  6178508   724839
# 233521            Kong Georgs Vej 110, 2000 Frederiksberg  6177225   721865
# 233522                  Niels Bohrs Allé 1, 5230 Odense M  6137182   588694
# 233523               Roers Allé 16, Tarup, 5210 Odense NV  6141099   585144
#
#         tilkomnr  formaal
# 0          223.0     23.0
# 1          223.0      1.0
# 2          230.0     43.0
# 3          230.0      1.0
# 4          350.0     31.0
# ...          ...      ...
# 233519     259.0     51.0
# 233520     101.0      1.0
# 233521     147.0      1.0
# 233522     461.0     11.0
# 233523     461.0      1.0
#
# [233524 rows x 12 columns]

# %%
cols_to_int = ['tiladrstedid','tilkomnr', 'formaal' ]
for col in cols_to_int:
    if col in df_Ture.columns:
        df_Ture[col] = pd.to_numeric(df_Ture[col], errors='coerce').astype('Int64')

# %%
cols_to_int = ['tiladre', 'tiladrn', 'destmuncode', 'tiladrstedid', 'turnr']
for col in cols_to_int:
    if col in after_Ture.columns:
        after_Ture[col] = pd.to_numeric(after_Ture[col], errors='coerce').astype('Int64')

# %%
after_Ture.rename(columns={'destmuncode':'tilkomnr'}, inplace=True)

# %%
# Identify common columns
common_cols = sorted(set(df_Ture.columns).intersection(after_Ture.columns))
compare_cols = [c for c in common_cols if c != "turid"]  # skip merge key

# Assign likely numeric vs text 
numeric_cols = [c for c in compare_cols if c in ["turnr","tiladrid","tiladrstedid","tiladrn", "tiladre"]]
text_cols    = [c for c in compare_cols if c in ["tiladrtext"]]

# Any leftover goes to text
for c in compare_cols:
    if c not in numeric_cols and c not in text_cols:
        text_cols.append(c)

print("Compare cols:", compare_cols)
print("Numeric cols:", numeric_cols)
print("Text cols:", text_cols)
# Out:
# Compare cols: ['tiladre', 'tiladrid', 'tiladrn', 'tiladrstedid', 'tiladrtext', 'tilkomnr', 'turnr']
# Numeric cols: ['tiladre', 'tiladrid', 'tiladrn', 'tiladrstedid', 'turnr']
# Text cols: ['tiladrtext', 'tilkomnr']

# %%
# Merge on turid
m = df_Ture.merge(after_Ture, on="turid", suffixes=("_raw","_mod"), how="inner")
print("Merged shape:", m.shape)

# Normalize numeric columns to nullable Int64
for c in numeric_cols:
    m[f"{c}_raw"] = pd.to_numeric(m[f"{c}_raw"], errors="coerce").astype("Int64")
    m[f"{c}_mod"] = pd.to_numeric(m[f"{c}_mod"], errors="coerce").astype("Int64")

# Normalize text columns (strip, lower, keep NA as NA)
for c in text_cols:
    m[f"{c}_raw"] = m[f"{c}_raw"].where(m[f"{c}_raw"].notna(), pd.NA).astype("string").str.strip().str.lower()
    m[f"{c}_mod"] = m[f"{c}_mod"].where(m[f"{c}_mod"].notna(), pd.NA).astype("string").str.strip().str.lower()
# Out:
# Merged shape: (233524, 21)

# %%
diff_masks = {}
for c in compare_cols:
    left  = m[f"{c}_raw"]
    right = m[f"{c}_mod"]
    # "changed" means values are different AND modified is not NA
    changed = right.notna() & (~right.eq(left))
    diff_masks[c] = changed

# Trip-level flag
any_changed = pd.DataFrame(diff_masks).any(axis=1)
m["flag"] = m["turid"].where(any_changed, "OK").mask(any_changed, "WRONG")

print("Total trips:", len(m))
print("Corrected trips:", (m["flag"]=="WRONG").sum())
print("% corrected:", (m["flag"]=="WRONG").mean()*100)
show_scrollable(m, max_rows=30)
# Out:
# Total trips: 233524
# Corrected trips: 28327
# % corrected: 12.130230725749817
# <div style="overflow:auto; height:400px"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>turid</th>
#       <th>sessionid</th>
#       <th>turnr_raw</th>
#       <th>tiladrflag</th>
#       <th>tiladrsogeord</th>
#       <th>tiladrid_raw</th>
#       <th>tiladrstedid_raw</th>
#       <th>tiladrtext_raw</th>
#       <th>tiladrn_raw</th>
#       <th>tiladre_raw</th>
#       <th>tilkomnr_raw</th>
#       <th>formaal</th>
#       <th>medtagtur</th>
#       <th>turnr_mod</th>
#       <th>tiladrid_mod</th>
#       <th>tiladrstedid_mod</th>
#       <th>tiladrtext_mod</th>
#       <th>tiladrn_mod</th>
#       <th>tiladre_mod</th>
#       <th>tilkomnr_mod</th>
#       <th>tiladrkonklu</th>
#       <th>flag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2118077</td>
#       <td>347009</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Ahornvej 30 2970 Hørshol</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>ahornvej 30, 2970 hørsholm</td>
#       <td>6199137</td>
#       <td>718433</td>
#       <td>223</td>
#       <td>23</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2118078</td>
#       <td>347009</td>
#       <td>2</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>bellisvej 38, 2970 hørsholm</td>
#       <td>6198520</td>
#       <td>718307</td>
#       <td>223</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2118081</td>
#       <td>347010</td>
#       <td>3</td>
#       <td>4</td>
#       <td>Høsterkøb kirke</td>
#       <td>&lt;NA&gt;</td>
#       <td>166952</td>
#       <td>høsterkøb kirke, gøngehusvej 286, 2970 hørsholm</td>
#       <td>6195042</td>
#       <td>718391</td>
#       <td>230</td>
#       <td>43</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2118082</td>
#       <td>347010</td>
#       <td>4</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>keilstruplund 83, 3460 birkerød</td>
#       <td>6193548</td>
#       <td>715687</td>
#       <td>230</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2118083</td>
#       <td>347013</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Gevninge Bygade 2 4000</td>
#       <td>&lt;NA&gt;</td>
#       <td>158249</td>
#       <td>dagli´brugsen, gevninge bygade 2, gevninge, 40...</td>
#       <td>6170097</td>
#       <td>686374</td>
#       <td>350</td>
#       <td>31</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2118084</td>
#       <td>347013</td>
#       <td>2</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>herslevvej 12, trællerup, 4000 roskilde</td>
#       <td>6172090</td>
#       <td>686952</td>
#       <td>350</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2118087</td>
#       <td>347015</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Dalgas allé 7800</td>
#       <td>&lt;NA&gt;</td>
#       <td>221795</td>
#       <td>fakta 0151, dalgas alle 18, 7800 skive</td>
#       <td>6267816</td>
#       <td>500884</td>
#       <td>779</td>
#       <td>11</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2118088</td>
#       <td>347015</td>
#       <td>2</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>vejlgårdvej 26, rønbjerg, 7800 skive</td>
#       <td>6266008</td>
#       <td>495786</td>
#       <td>779</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2118090</td>
#       <td>347016</td>
#       <td>1</td>
#       <td>2</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>lærkegårdsvænget 5, ordrup, 4540 fårevejle</td>
#       <td>6189478</td>
#       <td>651675</td>
#       <td>306</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>6189479</td>
#       <td>651680</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>WRONG</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2118092</td>
#       <td>347017</td>
#       <td>1</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>hirsevej 17, 5800 nyborg</td>
#       <td>6132795</td>
#       <td>614111</td>
#       <td>450</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>OK</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2118093</td>
#       <td>347017</td>
#       <td>2</td>
#       <td>4</td>
#       <td>Middelfart</td>
#       <td>-1</td>
#       <td>-1</td>
#       <td>tankstation</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>31</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>arlavej 2, 6070 christiansfeld</td>
#       <td>6134425</td>
#       <td>531366</td>
#       <td>621</td>
#       <td>4</td>
#       <td>WRONG</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2118096</td>
#       <td>347021</td>
#       <td>1</td>
#       <td>4</td>
#       <td>Kirkevær løsevej 3500</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>kirke værløsevej 20, 3500 værløse</td>
#       <td>6186967</td>
#       <td>710998</td>
#       <td>190</td>
#       <td>42</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>6186963</td>
#       <td>710998</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>WRONG</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2118097</td>
#       <td>347021</td>
#       <td>2</td>
#       <td>1</td>
#       <td>NaN</td>
#       <td>&lt;NA&gt;</td>
#       <td>0</td>
#       <td>enebærhaven 39, 3500 værløse</td>
#       <td>6187115</td>
#       <td>709637</td>
#       <td>190</td>
#       <td>1</td>
#       <td>0</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>

# %%
m.columns
# Out:
# Index(['turid', 'sessionid', 'turnr_raw', 'tiladrflag', 'tiladrsogeord',
#        'tiladrid_raw', 'tiladrstedid_raw', 'tiladrtext_raw', 'tiladrn_raw',
#        'tiladre_raw', 'tilkomnr_raw', 'formaal', 'medtagtur', 'turnr_mod',
#        'tiladrid_mod', 'tiladrstedid_mod', 'tiladrtext_mod', 'tiladrn_mod',
#        'tiladre_mod', 'tilkomnr_mod', 'tiladrkonklu', 'flag'],
#       dtype='object')

# %%
df_t = m.copy()  # Use merged dataframe for further analysis
df_t.drop(columns=['turnr_raw', 'tiladrflag',
       'tiladrid_raw', 'tiladrstedid_raw', 'tilkomnr_raw', 'formaal', 'medtagtur', 'turnr_mod',
       'tiladrid_mod', 'tiladrstedid_mod', 'tilkomnr_mod', 'tiladrkonklu', 'flag'], inplace=True)

# %%
# Build a boolean DataFrame: rows=trips, cols=fields, value=True if that field changed
diff_df = pd.DataFrame(diff_masks)  # same index as m

# List of changed columns per row - handle NA values by replacing them with False
m["changed_cols"] = diff_df.apply(lambda r: [c for c, v in r.items() if pd.notna(v) and v], axis=1)

# %%
tur_edit = m[['turid', 'sessionid', 'tiladrsogeord', 'tiladrtext_raw', 'flag', 'changed_cols']]

# %%
df_t
# Out:
#           turid  sessionid             tiladrsogeord  \
# 0       2118077     347009  Ahornvej 30 2970 Hørshol
# 1       2118078     347009                       NaN
# 2       2118081     347010           Høsterkøb kirke
# 3       2118082     347010                       NaN
# 4       2118083     347013    Gevninge Bygade 2 4000
# ...         ...        ...                       ...
# 233519  2747013     538780      Havnen 27, 4600 Køge
# 233520  2747014     538780                       NaN
# 233521  2747056     538797                       NaN
# 233522  2747120     538818                       NaN
# 233523  2747123     538818                       NaN
#
#                                            tiladrtext_raw  tiladrn_raw  \
# 0                              ahornvej 30, 2970 hørsholm      6199137
# 1                             bellisvej 38, 2970 hørsholm      6198520
# 2         høsterkøb kirke, gøngehusvej 286, 2970 hørsholm      6195042
# 3                         keilstruplund 83, 3460 birkerød      6193548
# 4       dagli´brugsen, gevninge bygade 2, gevninge, 40...      6170097
# ...                                                   ...          ...
# 233519                               havnen 27, 4600 køge      6150077
# 233520            nordre frihavnsgade 5, 2100 københavn ø      6178508
# 233521            kong georgs vej 110, 2000 frederiksberg      6177225
# 233522                  niels bohrs allé 1, 5230 odense m      6137182
# 233523               roers allé 16, tarup, 5210 odense nv      6141099
#
#         tiladre_raw tiladrtext_mod  tiladrn_mod  tiladre_mod
# 0            718433           <NA>         <NA>         <NA>
# 1            718307           <NA>         <NA>         <NA>
# 2            718391           <NA>         <NA>         <NA>
# 3            715687           <NA>         <NA>         <NA>
# 4            686374           <NA>         <NA>         <NA>
# ...             ...            ...          ...          ...
# 233519       701552           <NA>         <NA>         <NA>
# 233520       724839           <NA>         <NA>         <NA>
# 233521       721865           <NA>         <NA>         <NA>
# 233522       588694           <NA>         <NA>         <NA>
# 233523       585144           <NA>         <NA>         <NA>
#
# [233524 rows x 9 columns]

# %%
df_t.to_csv('Data/EfterkodTur_Edited_Nicola.csv', index=False, encoding='latin1')

# %%
# tur_edit.to_csv('Data/TuTur_Edited_Nicola.csv', index=False, encoding='latin1')

# %% [markdown]
# ## From here we can check and analyze the processed data, with the retriever

# %% [markdown]
# On the file 'process_csv' we use as upload file 'TuTur_Edited_Nicola' , process it and save it as 'TuTur_Test'

# %%
df_tur_test = pd.read_csv('Data/TuTur_Test.csv', encoding='latin1')

# %%
df_tur_test = df_tur_test.iloc[:, [0,1,2,3,6,7,8,9,10,11,4,5]]
df_tur_test['% opt 1'] = df_tur_test['% opt 1'].round().astype('Int64')
df_tur_test['% opt 2'] = df_tur_test['% opt 2'].round().astype('Int64')
df_tur_test['% opt 3'] = df_tur_test['% opt 3'].round().astype('Int64')

# %%
show_scrollable(df_tur_test, max_rows=50)
# Out:
# <div style="overflow:auto; height:400px"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>turid</th>
#       <th>sessionid</th>
#       <th>tiladrsogeord</th>
#       <th>tiladrtext_raw</th>
#       <th>option 1</th>
#       <th>% opt 1</th>
#       <th>option 2</th>
#       <th>% opt 2</th>
#       <th>option 3</th>
#       <th>% opt 3</th>
#       <th>flag</th>
#       <th>changed_cols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2118077</td>
#       <td>347009</td>
#       <td>Ahornvej 30 2970 HÃ¸rshol</td>
#       <td>ahornvej 30, 2970 hÃ¸rsholm</td>
#       <td>Ahornvej 30, 2970 HÃ¸rsholm</td>
#       <td>100</td>
#       <td>Ahornvej 30, 2791 DragÃ¸r</td>
#       <td>80</td>
#       <td>Ahornvej 30, 3630 JÃ¦gerspris</td>
#       <td>80</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2118078</td>
#       <td>347009</td>
#       <td>NaN</td>
#       <td>bellisvej 38, 2970 hÃ¸rsholm</td>
#       <td>Bellisvej 38, 2970 HÃ¸rsholm</td>
#       <td>100</td>
#       <td>Bellisvej 38, 4000 Roskilde</td>
#       <td>80</td>
#       <td>Bellisvej 38, 5000 Odense C</td>
#       <td>80</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2118081</td>
#       <td>347010</td>
#       <td>HÃ¸sterkÃ¸b kirke</td>
#       <td>hÃ¸sterkÃ¸b kirke, gÃ¸ngehusvej 286, 2970 hÃ¸r...</td>
#       <td>GÃ¸ngehusvej 286, 2970 HÃ¸rsholm</td>
#       <td>100</td>
#       <td>GÃ¸ngehusvej 38, 2950 VedbÃ¦k</td>
#       <td>70</td>
#       <td>Husvej 11, 7884 Fur</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2118082</td>
#       <td>347010</td>
#       <td>NaN</td>
#       <td>keilstruplund 83, 3460 birkerÃ¸d</td>
#       <td>Keilstruplund 83, 3460 BirkerÃ¸d</td>
#       <td>100</td>
#       <td>Kelstruplund 1, 4560 Vig</td>
#       <td>65</td>
#       <td>Lystruplund 78, 8520 Lystrup</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2118083</td>
#       <td>347013</td>
#       <td>Gevninge Bygade 2 4000</td>
#       <td>dagliÂ´brugsen, gevninge bygade 2, gevninge, 4...</td>
#       <td>Gevninge Bygade 7B, 4000 Roskilde</td>
#       <td>90</td>
#       <td>Bygade 2, 7160 TÃ¸rring</td>
#       <td>65</td>
#       <td>Genner Bygade 2, 6230 RÃ¸dekro</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2118084</td>
#       <td>347013</td>
#       <td>NaN</td>
#       <td>herslevvej 12, trÃ¦llerup, 4000 roskilde</td>
#       <td>Herslevvej 12, 4000 Roskilde</td>
#       <td>100</td>
#       <td>Herslevvej 12, 5900 RudkÃ¸bing</td>
#       <td>80</td>
#       <td>Herslevvejen 12, 4270 HÃ¸ng</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2118087</td>
#       <td>347015</td>
#       <td>Dalgas allÃ© 7800</td>
#       <td>fakta 0151, dalgas alle 18, 7800 skive</td>
#       <td>Dalgas Alle 18, 7800 Skive</td>
#       <td>100</td>
#       <td>BrÃ¸nshÃ¸jholms AllÃ© 18, 2700 BrÃ¸nshÃ¸j</td>
#       <td>65</td>
#       <td>Amalie Skrams AllÃ© 18, 2500 Valby</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2118088</td>
#       <td>347015</td>
#       <td>NaN</td>
#       <td>vejlgÃ¥rdvej 26, rÃ¸nbjerg, 7800 skive</td>
#       <td>VejlgÃ¥rdvej 26, 7800 Skive</td>
#       <td>100</td>
#       <td>VelgÃ¥rdevej 26, 8766 NÃ¸rre Snede</td>
#       <td>65</td>
#       <td>SvejgÃ¥rdsvej 26, 2900 Hellerup</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2118090</td>
#       <td>347016</td>
#       <td>NaN</td>
#       <td>lÃ¦rkegÃ¥rdsvÃ¦nget 5, ordrup, 4540 fÃ¥revejle</td>
#       <td>LÃ¦rkegÃ¥rdsvÃ¦nget 5, 4540 FÃ¥revejle</td>
#       <td>100</td>
#       <td>VÃ¦nget 5, 2630 Taastrup</td>
#       <td>65</td>
#       <td>VÃ¦nget 5, 3050 HumlebÃ¦k</td>
#       <td>65</td>
#       <td>WRONG</td>
#       <td>['tiladre', 'tiladrn']</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2118092</td>
#       <td>347017</td>
#       <td>NaN</td>
#       <td>hirsevej 17, 5800 nyborg</td>
#       <td>Hirsevej 17, 5800 Nyborg</td>
#       <td>100</td>
#       <td>Hirsevej 17, 2700 BrÃ¸nshÃ¸j</td>
#       <td>80</td>
#       <td>Hirsevej 17, 4040 Jyllinge</td>
#       <td>80</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2118093</td>
#       <td>347017</td>
#       <td>Middelfart</td>
#       <td>tankstation</td>
#       <td>Ved Brandstationen 1, 2600 Glostrup</td>
#       <td>59</td>
#       <td>Brandstation Vestvej 50A, 2770 Kastrup</td>
#       <td>59</td>
#       <td>Snekkersten Stationsvej 3, 3070 Snekkersten</td>
#       <td>59</td>
#       <td>WRONG</td>
#       <td>['tiladre', 'tiladrn', 'tiladrstedid', 'tiladr...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2118096</td>
#       <td>347021</td>
#       <td>KirkevÃ¦r lÃ¸sevej 3500</td>
#       <td>kirke vÃ¦rlÃ¸sevej 20, 3500 vÃ¦rlÃ¸se</td>
#       <td>Kirke VÃ¦rlÃ¸sevej 20, 3500 VÃ¦rlÃ¸se</td>
#       <td>100</td>
#       <td>Kirke AllÃ© 20, 4970 RÃ¸dby</td>
#       <td>65</td>
#       <td>Kirke AllÃ© 20, 6862 Tistrup</td>
#       <td>65</td>
#       <td>WRONG</td>
#       <td>['tiladrn']</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2118097</td>
#       <td>347021</td>
#       <td>NaN</td>
#       <td>enebÃ¦rhaven 39, 3500 vÃ¦rlÃ¸se</td>
#       <td>EnebÃ¦rhaven 39, 3500 VÃ¦rlÃ¸se</td>
#       <td>100</td>
#       <td>EnebÃ¦rhaven 39, 2620 Albertslund</td>
#       <td>80</td>
#       <td>EnebÃ¦rvej 39, 4500 NykÃ¸bing Sj</td>
#       <td>64</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2118105</td>
#       <td>347028</td>
#       <td>Diget 60,2600 Glostrup</td>
#       <td>diget 60, 2600 glostrup</td>
#       <td>Diget 60, 2600 Glostrup</td>
#       <td>100</td>
#       <td>Vierdiget 60, 2791 DragÃ¸r</td>
#       <td>65</td>
#       <td>Stendiget 60, 2630 Taastrup</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2118106</td>
#       <td>347028</td>
#       <td>Hovedvejen 152,2600 Glostrup</td>
#       <td>hovedvejen 152a, 2600 glostrup</td>
#       <td>Hovedvejen 152A, 2600 Glostrup</td>
#       <td>100</td>
#       <td>Hovedvejen 151B, 4320 Lejre</td>
#       <td>70</td>
#       <td>Hovedvejen 154, 4733 TappernÃ¸je</td>
#       <td>70</td>
#       <td>WRONG</td>
#       <td>['tiladre', 'tiladrn']</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2118107</td>
#       <td>347028</td>
#       <td>MjÃ¸lnersvej 1</td>
#       <td>mjÃ¸lnersvej 1, 2600 glostrup</td>
#       <td>MjÃ¸lnersvej 1, 2600 Glostrup</td>
#       <td>100</td>
#       <td>MjÃ¸lnersvej 1, 8920 Randers NV</td>
#       <td>80</td>
#       <td>MjÃ¸lnersvej 1, 8800 Viborg</td>
#       <td>80</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2118108</td>
#       <td>347028</td>
#       <td>NaN</td>
#       <td>kirkebjerg allÃ© 118, 2605 brÃ¸ndby</td>
#       <td>Kirkebjerg AllÃ© 118, 2605 BrÃ¸ndby</td>
#       <td>100</td>
#       <td>RÃ¸nne Alle 118, 7451 Sunds</td>
#       <td>65</td>
#       <td>Park Alle 118, 7600 Struer</td>
#       <td>65</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2118109</td>
#       <td>347030</td>
#       <td>Vestergade 63,8550 RyomgÃ¥rd</td>
#       <td>vestergade 63, 8550 ryomgÃ¥rd</td>
#       <td>Vestergade 63, 8550 RyomgÃ¥rd</td>
#       <td>100</td>
#       <td>Vestergade 63, 4000 Roskilde</td>
#       <td>80</td>
#       <td>Vestergade 63, 3200 Helsinge</td>
#       <td>80</td>
#       <td>OK</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2118110</td>
#       <td>347030</td>
#       <td>NaN</td>
#       <td>syrenvej 1, pindstrup, 8550 ryomgÃ¥rd</td>
#       <td>Syrenvej 1, 8550 RyomgÃ¥rd</td>
#       <td>100</td>
#       <td>Syrenvej 1, 3100 HornbÃ¦
